# %%
#Importing Necessary Packages
import requests
import os
import urllib3
import itertools 
import re
import urllib.request
import pandas as pd
import numpy as np
os.chdir("C:\\Users\\Rahul\\Desktop\\Python Programs\\Machine Learning\\DataSets\\Used Cars v3")

# %%
## From zigwheels Main Page fetching html source code

## Fetching Main File HTML code
response =urllib.request.urlopen('https://www.zigwheels.com/newcars/')
html = response.read()
text = html.decode()

##Fetching All Brand Names from HTML data and saving all as brands list
#brands=re.findall('a href="(/newcars/([A-Za-z\-0-9]*))" title=',text)
brands=re.findall('a href="(/newcars/([A-Za-z\-0-9]*))" ',text)
brands=list(itertools.chain(*brands))
## Converting brands names in website links by concatenating cardekho.com for further data scrapping
link_list=[]
count=0
for i in brands:
    if count%2==0:
        link_list.append('https://www.zigwheels.com'+i)
    else:
        link_list.append(i) 
    count+=1
link_list
# Out:
# ['https://www.zigwheels.com/newcars/Maruti-Suzuki',
#  'Maruti-Suzuki',
#  'https://www.zigwheels.com/newcars/Honda',
#  'Honda',
#  'https://www.zigwheels.com/newcars/Hyundai',
#  'Hyundai',
#  'https://www.zigwheels.com/newcars/Mahindra',
#  'Mahindra',
#  'https://www.zigwheels.com/newcars/Tata',
#  'Tata',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki',
#  'Maruti-Suzuki',
#  'https://www.zigwheels.com/newcars/MG-Motor',
#  'MG-Motor',
#  'https://www.zigwheels.com/newcars/Hyundai',
#  'Hyundai',
#  'https://www.zigwheels.com/newcars/Honda',
#  'Honda',
#  'https://www.zigwheels.com/newcars/Toyota',
#  'Toyota',
#  'https://www.zigwheels.com/newcars/Mahindra',
#  'Mahindra',
#  'https://www.zigwheels.com/newcars/Tata',
#  'Tata',
#  'https://www.zigwheels.com/newcars/Kia',
#  'Kia',
#  'https://www.zigwheels.com/newcars/Jeep',
#  'Jeep',
#  'https://www.zigwheels.com/newcars/Volkswagen',
#  'Volkswagen',
#  'https://www.zigwheels.com/newcars/Ford',
#  'Ford',
#  'https://www.zigwheels.com/newcars/Renault',
#  'Renault',
#  'https://www.zigwheels.com/newcars/BMW',
#  'BMW',
#  'https://www.zigwheels.com/newcars/Audi',
#  'Audi',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz',
#  'Mercedes-Benz',
#  'https://www.zigwheels.com/newcars/Skoda',
#  'Skoda',
#  'https://www.zigwheels.com/newcars/Datsun',
#  'Datsun',
#  'https://www.zigwheels.com/newcars/Mitsubishi',
#  'Mitsubishi',
#  'https://www.zigwheels.com/newcars/Volvo',
#  'Volvo',
#  'https://www.zigwheels.com/newcars/Nissan',
#  'Nissan',
#  'https://www.zigwheels.com/newcars/Fiat',
#  'Fiat',
#  'https://www.zigwheels.com/newcars/Jaguar',
#  'Jaguar',
#  'https://www.zigwheels.com/newcars/Lamborghini',
#  'Lamborghini',
#  'https://www.zigwheels.com/newcars/Rolls-Royce',
#  'Rolls-Royce',
#  'https://www.zigwheels.com/newcars/MINI',
#  'MINI',
#  'https://www.zigwheels.com/newcars/Tesla',
#  'Tesla',
#  'https://www.zigwheels.com/newcars/Bugatti',
#  'Bugatti',
#  'https://www.zigwheels.com/newcars/Porsche',
#  'Porsche',
#  'https://www.zigwheels.com/newcars/Aston-Martin',
#  'Aston-Martin',
#  'https://www.zigwheels.com/newcars/Ferrari',
#  'Ferrari',
#  'https://www.zigwheels.com/newcars/Land-Rover',
#  'Land-Rover',
#  'https://www.zigwheels.com/newcars/Maserati',
#  'Maserati',
#  'https://www.zigwheels.com/newcars/Bentley',
#  'Bentley',
#  'https://www.zigwheels.com/newcars/ISUZU',
#  'ISUZU',
#  'https://www.zigwheels.com/newcars/Force-Motors',
#  'Force-Motors',
#  'https://www.zigwheels.com/newcars/Bajaj',
#  'Bajaj',
#  'https://www.zigwheels.com/newcars/DC',
#  'DC',
#  'https://www.zigwheels.com/newcars/Lexus',
#  'Lexus',
#  'https://www.zigwheels.com/newcars/Premier',
#  'Premier',
#  'https://www.zigwheels.com/newcars/Chevrolet',
#  'Chevrolet',
#  'https://www.zigwheels.com/newcars/citroen',
#  'citroen',
#  'https://www.zigwheels.com/newcars/best-diesel-cars',
#  'best-diesel-cars',
#  'https://www.zigwheels.com/newcars/best-petrol-cars',
#  'best-petrol-cars',
#  'https://www.zigwheels.com/newcars/hybrid-cars',
#  'hybrid-cars',
#  'https://www.zigwheels.com/newcars/electric-cars',
#  'electric-cars',
#  'https://www.zigwheels.com/newcars/best-manual-cars',
#  'best-manual-cars',
#  'https://www.zigwheels.com/newcars/best-automatic-cars',
#  'best-automatic-cars']

# %%
len(link_list)
# Out:
# 94

# %%
# Fetching Brands of All Models via link list created above one by one
count1=0
link_model=[]
for i in link_list:
    #k=i.lower()                                   # to lower brand name for site compatible
    
# Traversing model links using brand name and adding in link_model list
# if count divisible by zero then open link and then in next iteration fetching model and concating link in model_list

    if count1%2==0:
        count1+=1
        k=i
        response =urllib.request.urlopen(i)
        html = response.read()
        text = html.decode()
    else:
        count1+=1
       # regex_m1=re.compile(r'href="/'+k+'/(.*?)">|href="/carmodels/'+i+'/(.*?)">')
    
#Using regex for pattern matching of models as per html souce code recd from above reuqest
        #regex_m1=re.compile(i+'"(/[A-Z,a-z,-]*)" title=')
        regex_m1=re.compile('a href="'+k+'(/[A-Za-z\-0-9]*)" ')
        #print("'a href="+k+'/(.*?)" title=')
        #regex_m1=re.compile('a href="'+k+'/(.*?)" title=')

        model1=re.findall(regex_m1,text)
        #model2=re.findall(regex_m2,text)
        for j in model1:
            link_model.append(k+j) 
        #for j in model2:
         #   link_model.append('https://www.cardekho.com/carmodels/'+i+'/'+j)

# %%
print(len(link_model))
link_model
# Out:
# 548
# ['https://www.zigwheels.com/newcars/Maruti-Suzuki/s-presso',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/xl6',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Baleno',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Swift',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/WAGONR',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Alto-800',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/ertiga',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Swift-Dzire',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Vitara-Brezza',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Alto-K10',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Celerio',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Ciaz',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Eeco',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Ignis',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/S-Cross',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/celerio-x',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/baleno-rs',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/xl5',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/jimny',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Grand-Vitara',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/wagonr-electric',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/800',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/a-star',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/esteem',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/estilo',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Gypsy',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/Omni',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/ritz',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/sx4',
#  'https://www.zigwheels.com/newcars/Maruti-Suzuki/zen',
#  'https://www.zigwheels.com/newcars/MG-Motor/hector',
#  'https://www.zigwheels.com/newcars/MG-Motor/ezs',
#  'https://www.zigwheels.com/newcars/MG-Motor/erx5',
#  'https://www.zigwheels.com/newcars/MG-Motor/gs',
#  'https://www.zigwheels.com/newcars/MG-Motor/baojun-510',
#  'https://www.zigwheels.com/newcars/MG-Motor/rx5',
#  'https://www.zigwheels.com/newcars/Hyundai/venue',
#  'https://www.zigwheels.com/newcars/Hyundai/Creta',
#  'https://www.zigwheels.com/newcars/Hyundai/Elite-i20',
#  'https://www.zigwheels.com/newcars/Hyundai/Grand-i10',
#  'https://www.zigwheels.com/newcars/Hyundai/kona',
#  'https://www.zigwheels.com/newcars/Hyundai/Verna',
#  'https://www.zigwheels.com/newcars/Hyundai/grand-i10-nios',
#  'https://www.zigwheels.com/newcars/Hyundai/Santro',
#  'https://www.zigwheels.com/newcars/Hyundai/Xcent',
#  'https://www.zigwheels.com/newcars/Hyundai/i20-Active',
#  'https://www.zigwheels.com/newcars/Hyundai/elantra',
#  'https://www.zigwheels.com/newcars/Hyundai/Tucson',
#  'https://www.zigwheels.com/newcars/Hyundai/xcent-2020',
#  'https://www.zigwheels.com/newcars/Hyundai/creta-2020',
#  'https://www.zigwheels.com/newcars/Hyundai/santa-fe-2019',
#  'https://www.zigwheels.com/newcars/Hyundai/sonata',
#  'https://www.zigwheels.com/newcars/Hyundai/palisade',
#  'https://www.zigwheels.com/newcars/Hyundai/verna-2020',
#  'https://www.zigwheels.com/newcars/Hyundai/elite-i20-2020',
#  'https://www.zigwheels.com/newcars/Hyundai/ioniq',
#  'https://www.zigwheels.com/newcars/Hyundai/accent',
#  'https://www.zigwheels.com/newcars/Hyundai/elantra-2015-2019',
#  'https://www.zigwheels.com/newcars/Hyundai/EON',
#  'https://www.zigwheels.com/newcars/Hyundai/getz',
#  'https://www.zigwheels.com/newcars/Hyundai/getz-prime',
#  'https://www.zigwheels.com/newcars/Hyundai/i10',
#  'https://www.zigwheels.com/newcars/Hyundai/santro-xing',
#  'https://www.zigwheels.com/newcars/Honda/Amaze',
#  'https://www.zigwheels.com/newcars/Honda/City',
#  'https://www.zigwheels.com/newcars/Honda/civic',
#  'https://www.zigwheels.com/newcars/Honda/wr-v',
#  'https://www.zigwheels.com/newcars/Honda/BRV',
#  'https://www.zigwheels.com/newcars/Honda/Accord',
#  'https://www.zigwheels.com/newcars/Honda/Jazz',
#  'https://www.zigwheels.com/newcars/Honda/cr-v',
#  'https://www.zigwheels.com/newcars/Honda/jazz-2020',
#  'https://www.zigwheels.com/newcars/Honda/brio-2019',
#  'https://www.zigwheels.com/newcars/Honda/city-2020',
#  'https://www.zigwheels.com/newcars/Honda/hr-v',
#  'https://www.zigwheels.com/newcars/Honda/vezel',
#  'https://www.zigwheels.com/newcars/Honda/Brio',
#  'https://www.zigwheels.com/newcars/Honda/mobilio',
#  'https://www.zigwheels.com/newcars/Toyota/Fortuner',
#  'https://www.zigwheels.com/newcars/Toyota/Innova-Crysta',
#  'https://www.zigwheels.com/newcars/Toyota/glanza',
#  'https://www.zigwheels.com/newcars/Toyota/Etios',
#  'https://www.zigwheels.com/newcars/Toyota/Etios-Liva',
#  'https://www.zigwheels.com/newcars/Toyota/Corolla-Altis',
#  'https://www.zigwheels.com/newcars/Toyota/yaris',
#  'https://www.zigwheels.com/newcars/Toyota/Land-Cruiser-200',
#  'https://www.zigwheels.com/newcars/Toyota/Camry',
#  'https://www.zigwheels.com/newcars/Toyota/Prado',
#  'https://www.zigwheels.com/newcars/Toyota/Etios-Cross',
#  'https://www.zigwheels.com/newcars/Toyota/Prius',
#  'https://www.zigwheels.com/newcars/Toyota/vellfire',
#  'https://www.zigwheels.com/newcars/Toyota/c-hr',
#  'https://www.zigwheels.com/newcars/Toyota/corolla-2020',
#  'https://www.zigwheels.com/newcars/Toyota/alphard',
#  'https://www.zigwheels.com/newcars/Toyota/commuter',
#  'https://www.zigwheels.com/newcars/Toyota/corona',
#  'https://www.zigwheels.com/newcars/Toyota/crown',
#  'https://www.zigwheels.com/newcars/Toyota/cynos',
#  'https://www.zigwheels.com/newcars/Toyota/estima',
#  'https://www.zigwheels.com/newcars/Toyota/innova',
#  'https://www.zigwheels.com/newcars/Toyota/majesta',
#  'https://www.zigwheels.com/newcars/Toyota/mr2',
#  'https://www.zigwheels.com/newcars/Toyota/prado',
#  'https://www.zigwheels.com/newcars/Toyota/premio',
#  'https://www.zigwheels.com/newcars/Toyota/previa',
#  'https://www.zigwheels.com/newcars/Toyota/qualis',
#  'https://www.zigwheels.com/newcars/Toyota/sera',
#  'https://www.zigwheels.com/newcars/Toyota/starlet',
#  'https://www.zigwheels.com/newcars/Toyota/tercel',
#  'https://www.zigwheels.com/newcars/Mahindra/Scorpio',
#  'https://www.zigwheels.com/newcars/Mahindra/xuv300',
#  'https://www.zigwheels.com/newcars/Mahindra/XUV-500',
#  'https://www.zigwheels.com/newcars/Mahindra/Thar',
#  'https://www.zigwheels.com/newcars/Mahindra/e2oplus',
#  'https://www.zigwheels.com/newcars/Mahindra/e-verito',
#  'https://www.zigwheels.com/newcars/Mahindra/TUV300',
#  'https://www.zigwheels.com/newcars/Mahindra/marazzo',
#  'https://www.zigwheels.com/newcars/Mahindra/KUV100',
#  'https://www.zigwheels.com/newcars/Mahindra/tuv-300-plus',
#  'https://www.zigwheels.com/newcars/Mahindra/Xylo',
#  'https://www.zigwheels.com/newcars/Mahindra/alturas-g4',
#  'https://www.zigwheels.com/newcars/Mahindra/bolero-power-plus',
#  'https://www.zigwheels.com/newcars/Mahindra/Verito-Vibe',
#  'https://www.zigwheels.com/newcars/Mahindra/Verito',
#  'https://www.zigwheels.com/newcars/Mahindra/xuv500-2020',
#  'https://www.zigwheels.com/newcars/Mahindra/s204',
#  'https://www.zigwheels.com/newcars/Mahindra/xuv300-electric',
#  'https://www.zigwheels.com/newcars/Mahindra/thar-2020',
#  'https://www.zigwheels.com/newcars/Mahindra/xuv-aero',
#  'https://www.zigwheels.com/newcars/Mahindra/ekuv100',
#  'https://www.zigwheels.com/newcars/Mahindra/armada',
#  'https://www.zigwheels.com/newcars/Mahindra/Bolero',
#  'https://www.zigwheels.com/newcars/Mahindra/e2o',
#  'https://www.zigwheels.com/newcars/Mahindra/rexton',
#  'https://www.zigwheels.com/newcars/Mahindra/ingenio',
#  'https://www.zigwheels.com/newcars/Mahindra/jeep',
#  'https://www.zigwheels.com/newcars/Mahindra/logan',
#  'https://www.zigwheels.com/newcars/Mahindra/marshal',
#  'https://www.zigwheels.com/newcars/Mahindra/NuvoSport',
#  'https://www.zigwheels.com/newcars/Mahindra/quanto',
#  'https://www.zigwheels.com/newcars/Mahindra/s-201',
#  'https://www.zigwheels.com/newcars/Mahindra/supro',
#  'https://www.zigwheels.com/newcars/Mahindra/U321-MPV',
#  'https://www.zigwheels.com/newcars/Mahindra/voyager',
#  'https://www.zigwheels.com/newcars/Mahindra/willys',
#  'https://www.zigwheels.com/newcars/Mahindra/xuv700',
#  'https://www.zigwheels.com/newcars/Tata/harrier',
#  'https://www.zigwheels.com/newcars/Tata/Nexon',
#  'https://www.zigwheels.com/newcars/Tata/Tiago',
#  'https://www.zigwheels.com/newcars/Tata/tigor-ev',
#  'https://www.zigwheels.com/newcars/Tata/Hexa',
#  'https://www.zigwheels.com/newcars/Tata/Safari-STORME',
#  'https://www.zigwheels.com/newcars/Tata/Tigor',
#  'https://www.zigwheels.com/newcars/Tata/Zest',
#  'https://www.zigwheels.com/newcars/Tata/tiago-nrg',
#  'https://www.zigwheels.com/newcars/Tata/tiago-jtp',
#  'https://www.zigwheels.com/newcars/Tata/tigor-jtp',
#  'https://www.zigwheels.com/newcars/Tata/Bolt',
#  'https://www.zigwheels.com/newcars/Tata/altroz',
#  'https://www.zigwheels.com/newcars/Tata/evision',
#  'https://www.zigwheels.com/newcars/Tata/h2x',
#  'https://www.zigwheels.com/newcars/Tata/buzzard',
#  'https://www.zigwheels.com/newcars/Tata/nexon-ev',
#  'https://www.zigwheels.com/newcars/Tata/altroz-ev',
#  'https://www.zigwheels.com/newcars/Tata/h7x',
#  'https://www.zigwheels.com/newcars/Tata/tiago-ev',
#  'https://www.zigwheels.com/newcars/Tata/indica',
#  'https://www.zigwheels.com/newcars/Tata/Indica-eV2',
#  'https://www.zigwheels.com/newcars/Tata/Indigo-eCS',
#  'https://www.zigwheels.com/newcars/Tata/manza',
#  'https://www.zigwheels.com/newcars/Tata/Nano',
#  'https://www.zigwheels.com/newcars/Tata/safari',
#  'https://www.zigwheels.com/newcars/Tata/Sumo-Gold',
#  'https://www.zigwheels.com/newcars/Tata/Tiago-2016-2019',
#  'https://www.zigwheels.com/newcars/Tata/vista',
#  'https://www.zigwheels.com/newcars/Tata/winger',
#  'https://www.zigwheels.com/newcars/Kia/seltos',
#  'https://www.zigwheels.com/newcars/Kia/sportage',
#  'https://www.zigwheels.com/newcars/Kia/soul',
#  'https://www.zigwheels.com/newcars/Kia/stinger',
#  'https://www.zigwheels.com/newcars/Kia/rio',
#  'https://www.zigwheels.com/newcars/Kia/stonic',
#  'https://www.zigwheels.com/newcars/Kia/carnival',
#  'https://www.zigwheels.com/newcars/Jeep/compass',
#  'https://www.zigwheels.com/newcars/Jeep/trailhawk',
#  'https://www.zigwheels.com/newcars/Jeep/wrangler',
#  'https://www.zigwheels.com/newcars/Jeep/Grand-Cherokee',
#  'https://www.zigwheels.com/newcars/Jeep/compass-2020',
#  'https://www.zigwheels.com/newcars/Jeep/7-seater-suv',
#  'https://www.zigwheels.com/newcars/Jeep/Renegade',
#  'https://www.zigwheels.com/newcars/Jeep/Wrangler-2016-2019',
#  'https://www.zigwheels.com/newcars/Volkswagen/Tiguan',
#  'https://www.zigwheels.com/newcars/Volkswagen/vento',
#  'https://www.zigwheels.com/newcars/Volkswagen/polo',
#  'https://www.zigwheels.com/newcars/Volkswagen/Ameo',
#  'https://www.zigwheels.com/newcars/Volkswagen/virtus',
#  'https://www.zigwheels.com/newcars/Volkswagen/t-cross',
#  'https://www.zigwheels.com/newcars/Volkswagen/t-roc',
#  'https://www.zigwheels.com/newcars/Volkswagen/1600',
#  'https://www.zigwheels.com/newcars/Volkswagen/caravelle',
#  'https://www.zigwheels.com/newcars/Volkswagen/GTI',
#  'https://www.zigwheels.com/newcars/Volkswagen/multivan',
#  'https://www.zigwheels.com/newcars/Volkswagen/Passat-2015',
#  'https://www.zigwheels.com/newcars/Volkswagen/phaeton',
#  'https://www.zigwheels.com/newcars/Volkswagen/Polo-2015-2019',
#  'https://www.zigwheels.com/newcars/Volkswagen/polo-gti',
#  'https://www.zigwheels.com/newcars/Volkswagen/touareg',
#  'https://www.zigwheels.com/newcars/Volkswagen/Touareg',
#  'https://www.zigwheels.com/newcars/Volkswagen/Vento-2015-2019',
#  'https://www.zigwheels.com/newcars/Ford/EcoSport',
#  'https://www.zigwheels.com/newcars/Ford/mustang',
#  'https://www.zigwheels.com/newcars/Ford/endeavour',
#  'https://www.zigwheels.com/newcars/Ford/Figo',
#  'https://www.zigwheels.com/newcars/Ford/figo-aspire',
#  'https://www.zigwheels.com/newcars/Ford/freestyle',
#  'https://www.zigwheels.com/newcars/Ford/fiesta',
#  'https://www.zigwheels.com/newcars/Ford/ikon',
#  'https://www.zigwheels.com/newcars/Renault/triber',
#  'https://www.zigwheels.com/newcars/Renault/kwid',
#  'https://www.zigwheels.com/newcars/Renault/captur',
#  'https://www.zigwheels.com/newcars/Renault/duster',
#  'https://www.zigwheels.com/newcars/Renault/Lodgy',
#  'https://www.zigwheels.com/newcars/Renault/hbc',
#  'https://www.zigwheels.com/newcars/Renault/arkana',
#  'https://www.zigwheels.com/newcars/Renault/zoe',
#  'https://www.zigwheels.com/newcars/Renault/Kwid-2015-2019',
#  'https://www.zigwheels.com/newcars/Renault/Duster-2016-2019',
#  'https://www.zigwheels.com/newcars/Renault/fluence',
#  'https://www.zigwheels.com/newcars/Renault/koleos',
#  'https://www.zigwheels.com/newcars/Renault/Kwid-2015-2019',
#  'https://www.zigwheels.com/newcars/Renault/PULSE',
#  'https://www.zigwheels.com/newcars/Renault/scala',
#  'https://www.zigwheels.com/newcars/BMW/X1',
#  'https://www.zigwheels.com/newcars/BMW/z4',
#  'https://www.zigwheels.com/newcars/BMW/3-series-gt',
#  'https://www.zigwheels.com/newcars/BMW/x7',
#  'https://www.zigwheels.com/newcars/BMW/X5',
#  'https://www.zigwheels.com/newcars/BMW/3-series',
#  'https://www.zigwheels.com/newcars/BMW/x4',
#  'https://www.zigwheels.com/newcars/BMW/X6',
#  'https://www.zigwheels.com/newcars/BMW/7-series',
#  'https://www.zigwheels.com/newcars/BMW/6-Series-Gran-Coupe',
#  'https://www.zigwheels.com/newcars/BMW/m2',
#  'https://www.zigwheels.com/newcars/BMW/5-Series',
#  'https://www.zigwheels.com/newcars/BMW/m-series',
#  'https://www.zigwheels.com/newcars/BMW/X3',
#  'https://www.zigwheels.com/newcars/BMW/x6-2020',
#  'https://www.zigwheels.com/newcars/BMW/8-series',
#  'https://www.zigwheels.com/newcars/BMW/i3',
#  'https://www.zigwheels.com/newcars/BMW/1-series',
#  'https://www.zigwheels.com/newcars/BMW/3-Series-2015-2019',
#  'https://www.zigwheels.com/newcars/BMW/7-Series-2015-2019',
#  'https://www.zigwheels.com/newcars/BMW/x5-2014-2019',
#  'https://www.zigwheels.com/newcars/BMW/z3',
#  'https://www.zigwheels.com/newcars/BMW/Z4-2013-2018',
#  'https://www.zigwheels.com/newcars/Audi/A3',
#  'https://www.zigwheels.com/newcars/Audi/Q3',
#  'https://www.zigwheels.com/newcars/Audi/Q7',
#  'https://www.zigwheels.com/newcars/Audi/s5',
#  'https://www.zigwheels.com/newcars/Audi/A4',
#  'https://www.zigwheels.com/newcars/Audi/A5',
#  'https://www.zigwheels.com/newcars/Audi/A6',
#  'https://www.zigwheels.com/newcars/Audi/Q5',
#  'https://www.zigwheels.com/newcars/Audi/R8',
#  'https://www.zigwheels.com/newcars/Audi/rs5',
#  'https://www.zigwheels.com/newcars/Audi/A3-Cabriolet',
#  'https://www.zigwheels.com/newcars/Audi/RS7',
#  'https://www.zigwheels.com/newcars/Audi/q7-2020',
#  'https://www.zigwheels.com/newcars/Audi/a8-2019',
#  'https://www.zigwheels.com/newcars/Audi/Q2',
#  'https://www.zigwheels.com/newcars/Audi/e-tron',
#  'https://www.zigwheels.com/newcars/Audi/tt-2019',
#  'https://www.zigwheels.com/newcars/Audi/q3-2019',
#  'https://www.zigwheels.com/newcars/Audi/a7',
#  'https://www.zigwheels.com/newcars/Audi/q8',
#  'https://www.zigwheels.com/newcars/Audi/q4',
#  'https://www.zigwheels.com/newcars/Audi/a6-2019',
#  'https://www.zigwheels.com/newcars/Audi/a7-2011-2015',
#  'https://www.zigwheels.com/newcars/Audi/A8-L',
#  'https://www.zigwheels.com/newcars/Audi/RS6',
#  'https://www.zigwheels.com/newcars/Audi/s4',
#  'https://www.zigwheels.com/newcars/Audi/s6',
#  'https://www.zigwheels.com/newcars/Audi/TT',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/G-Class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/C-Class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/S-Class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/GLC',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/gla-class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/v-class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/E-Class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/e-class-all-terrain',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/GLE-Class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/CLA-Class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/GL-Class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/AMG-GT',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/GLS',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/A-Class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/B-Class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/CLS-Class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/glc-2019',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/b-class-2019',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/glb',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/cla-2020',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/gle-2019',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/a-class-sedan',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/gls-2020',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/eqc',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/cl-class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/clk-class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/g',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/gl-class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/gla-class-45-amg',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/M-Class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/m-class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/mb-class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/r-class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/s-class-cabriolet',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/sl-class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/SLC-Class',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/slk',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/sls-amg',
#  'https://www.zigwheels.com/newcars/Mercedes-Benz/viano',
#  'https://www.zigwheels.com/newcars/Skoda/Rapid',
#  'https://www.zigwheels.com/newcars/Skoda/Octavia',
#  'https://www.zigwheels.com/newcars/Skoda/kodiaq',
#  'https://www.zigwheels.com/newcars/Skoda/Superb',
#  'https://www.zigwheels.com/newcars/Skoda/octavia-2020',
#  'https://www.zigwheels.com/newcars/Skoda/citigo',
#  'https://www.zigwheels.com/newcars/Skoda/kamiq',
#  'https://www.zigwheels.com/newcars/Skoda/scala',
#  'https://www.zigwheels.com/newcars/Skoda/superb-2019',
#  'https://www.zigwheels.com/newcars/Skoda/karoq',
#  'https://www.zigwheels.com/newcars/Skoda/vision-x',
#  'https://www.zigwheels.com/newcars/Skoda/fabia',
#  'https://www.zigwheels.com/newcars/Skoda/laura',
#  'https://www.zigwheels.com/newcars/Skoda/octavia-combi',
#  'https://www.zigwheels.com/newcars/Skoda/yeti',
#  'https://www.zigwheels.com/newcars/Datsun/GO-Plus',
#  'https://www.zigwheels.com/newcars/Datsun/GO',
#  'https://www.zigwheels.com/newcars/Datsun/Redi-GO',
#  'https://www.zigwheels.com/newcars/Mitsubishi/Pajero-Sport',
#  'https://www.zigwheels.com/newcars/Mitsubishi/outlander',
#  'https://www.zigwheels.com/newcars/Mitsubishi/pajero-sport-2019',
#  'https://www.zigwheels.com/newcars/Mitsubishi/eclipse-cross',
#  'https://www.zigwheels.com/newcars/Mitsubishi/xpander',
#  'https://www.zigwheels.com/newcars/Mitsubishi/cedia',
#  'https://www.zigwheels.com/newcars/Mitsubishi/challenger',
#  'https://www.zigwheels.com/newcars/Mitsubishi/fto',
#  'https://www.zigwheels.com/newcars/Mitsubishi/lancer',
#  'https://www.zigwheels.com/newcars/Mitsubishi/lancer-evolution-x',
#  'https://www.zigwheels.com/newcars/Mitsubishi/Montero',
#  'https://www.zigwheels.com/newcars/Volvo/XC90',
#  'https://www.zigwheels.com/newcars/Volvo/s60-cross-country',
#  'https://www.zigwheels.com/newcars/Volvo/S90',
#  'https://www.zigwheels.com/newcars/Volvo/XC60',
#  'https://www.zigwheels.com/newcars/Volvo/xc40',
#  'https://www.zigwheels.com/newcars/Volvo/v90-cross-country',
#  'https://www.zigwheels.com/newcars/Volvo/S60',
#  'https://www.zigwheels.com/newcars/Volvo/v60-cross-country',
#  'https://www.zigwheels.com/newcars/Volvo/s60-2019',
#  'https://www.zigwheels.com/newcars/Volvo/s40',
#  'https://www.zigwheels.com/newcars/Volvo/s80',
#  'https://www.zigwheels.com/newcars/Volvo/V40',
#  'https://www.zigwheels.com/newcars/Volvo/V40-Cross-Country',
#  'https://www.zigwheels.com/newcars/Nissan/kicks',
#  'https://www.zigwheels.com/newcars/Nissan/Micra',
#  'https://www.zigwheels.com/newcars/Nissan/Terrano',
#  'https://www.zigwheels.com/newcars/Nissan/micra-active',
#  'https://www.zigwheels.com/newcars/Nissan/Sunny',
#  'https://www.zigwheels.com/newcars/Nissan/GTR',
#  'https://www.zigwheels.com/newcars/Nissan/sunny-2020',
#  'https://www.zigwheels.com/newcars/Nissan/note-e-power',
#  'https://www.zigwheels.com/newcars/Nissan/leaf',
#  'https://www.zigwheels.com/newcars/Nissan/terra',
#  'https://www.zigwheels.com/newcars/Nissan/X-Trail-2016',
#  'https://www.zigwheels.com/newcars/Nissan/350z',
#  'https://www.zigwheels.com/newcars/Nissan/370z',
#  'https://www.zigwheels.com/newcars/Nissan/evalia',
#  'https://www.zigwheels.com/newcars/Nissan/gloria',
#  'https://www.zigwheels.com/newcars/Nissan/jonga',
#  'https://www.zigwheels.com/newcars/Nissan/primera',
#  'https://www.zigwheels.com/newcars/Nissan/teana',
#  'https://www.zigwheels.com/newcars/Nissan/urvan',
#  'https://www.zigwheels.com/newcars/Fiat/Punto-Evo',
#  'https://www.zigwheels.com/newcars/Fiat/abarth-avventura',
#  'https://www.zigwheels.com/newcars/Fiat/Avventura-Urban-Cross',
#  'https://www.zigwheels.com/newcars/Fiat/Avventura',
#  'https://www.zigwheels.com/newcars/Fiat/Linea',
#  'https://www.zigwheels.com/newcars/Fiat/punto-abarth',
#  'https://www.zigwheels.com/newcars/Fiat/1100',
#  'https://www.zigwheels.com/newcars/Fiat/500',
#  'https://www.zigwheels.com/newcars/Fiat/abarth',
#  'https://www.zigwheels.com/newcars/Fiat/adventure',
#  'https://www.zigwheels.com/newcars/Fiat/ducato',
#  'https://www.zigwheels.com/newcars/Fiat/grande-punto',
#  'https://www.zigwheels.com/newcars/Fiat/Linea-Classic',
#  'https://www.zigwheels.com/newcars/Fiat/millicento',
#  'https://www.zigwheels.com/newcars/Fiat/palio',
#  'https://www.zigwheels.com/newcars/Fiat/palio-d',
#  'https://www.zigwheels.com/newcars/Fiat/palio-nv',
#  'https://www.zigwheels.com/newcars/Fiat/palio-nv',
#  'https://www.zigwheels.com/newcars/Fiat/palio-stile',
#  'https://www.zigwheels.com/newcars/Fiat/palio-stile',
#  'https://www.zigwheels.com/newcars/Fiat/petra',
#  'https://www.zigwheels.com/newcars/Fiat/petra-d',
#  'https://www.zigwheels.com/newcars/Fiat/premier-padmini',
#  'https://www.zigwheels.com/newcars/Fiat/punto',
#  'https://www.zigwheels.com/newcars/Fiat/Punto-Pure',
#  'https://www.zigwheels.com/newcars/Fiat/siena',
#  'https://www.zigwheels.com/newcars/Fiat/Siena-Weekend',
#  'https://www.zigwheels.com/newcars/Fiat/uno',
#  'https://www.zigwheels.com/newcars/Jaguar/XJ',
#  'https://www.zigwheels.com/newcars/Jaguar/XE',
#  'https://www.zigwheels.com/newcars/Jaguar/XF',
#  'https://www.zigwheels.com/newcars/Jaguar/F-Pace',
#  'https://www.zigwheels.com/newcars/Jaguar/F-Type',
#  'https://www.zigwheels.com/newcars/Jaguar/i-pace',
#  'https://www.zigwheels.com/newcars/Jaguar/xe-2019',
#  'https://www.zigwheels.com/newcars/Jaguar/e-pace',
#  'https://www.zigwheels.com/newcars/Jaguar/xk',
#  'https://www.zigwheels.com/newcars/Lamborghini/Huracan',
#  'https://www.zigwheels.com/newcars/Lamborghini/Aventador',
#  'https://www.zigwheels.com/newcars/Lamborghini/urus',
#  'https://www.zigwheels.com/newcars/Lamborghini/huracan-evo',
#  'https://www.zigwheels.com/newcars/Lamborghini/gallardo',
#  'https://www.zigwheels.com/newcars/Lamborghini/murcielago',
#  'https://www.zigwheels.com/newcars/Rolls-Royce/Phantom',
#  'https://www.zigwheels.com/newcars/Rolls-Royce/Dawn',
#  'https://www.zigwheels.com/newcars/Rolls-Royce/Ghost-Series-II',
#  'https://www.zigwheels.com/newcars/Rolls-Royce/Wraith',
#  'https://www.zigwheels.com/newcars/Rolls-Royce/cullinan',
#  'https://www.zigwheels.com/newcars/Rolls-Royce/drophead',
#  'https://www.zigwheels.com/newcars/MINI/cooper-clubman',
#  'https://www.zigwheels.com/newcars/MINI/5-Door',
#  'https://www.zigwheels.com/newcars/MINI/3-Door',
#  'https://www.zigwheels.com/newcars/MINI/Countryman',
#  'https://www.zigwheels.com/newcars/MINI/Convertible',
#  'https://www.zigwheels.com/newcars/MINI/cooper',
#  'https://www.zigwheels.com/newcars/Tesla/model-3',
#  'https://www.zigwheels.com/newcars/Tesla/model-x',
#  'https://www.zigwheels.com/newcars/Tesla/model-y',
#  'https://www.zigwheels.com/newcars/Tesla/model-s',
#  'https://www.zigwheels.com/newcars/Bugatti/divo',
#  'https://www.zigwheels.com/newcars/Bugatti/chiron',
#  'https://www.zigwheels.com/newcars/Bugatti/Veyron',
#  'https://www.zigwheels.com/newcars/Porsche/911',
#  'https://www.zigwheels.com/newcars/Porsche/Cayenne',
#  'https://www.zigwheels.com/newcars/Porsche/718',
#  'https://www.zigwheels.com/newcars/Porsche/macan',
#  'https://www.zigwheels.com/newcars/Porsche/Panamera',
#  'https://www.zigwheels.com/newcars/Porsche/cayenne-coupe',
#  'https://www.zigwheels.com/newcars/Porsche/taycan',
#  'https://www.zigwheels.com/newcars/Porsche/911',
#  'https://www.zigwheels.com/newcars/Porsche/boxster',
#  'https://www.zigwheels.com/newcars/Porsche/carrera-gt',
#  'https://www.zigwheels.com/newcars/Porsche/cayman',
#  'https://www.zigwheels.com/newcars/Porsche/Macan-2013-2019',
#  'https://www.zigwheels.com/newcars/Aston-Martin/DB11',
#  'https://www.zigwheels.com/newcars/Aston-Martin/Rapide',
#  'https://www.zigwheels.com/newcars/Aston-Martin/dbs-superleggera',
#  'https://www.zigwheels.com/newcars/Aston-Martin/dbx',
#  'https://www.zigwheels.com/newcars/Aston-Martin/zagato',
#  'https://www.zigwheels.com/newcars/Aston-Martin/db9',
#  'https://www.zigwheels.com/newcars/Aston-Martin/one-77',
#  'https://www.zigwheels.com/newcars/Aston-Martin/vanquish',
#  'https://www.zigwheels.com/newcars/Aston-Martin/vantage',
#  'https://www.zigwheels.com/newcars/Aston-Martin/virage',
#  'https://www.zigwheels.com/newcars/Ferrari/812-superfast',
#  'https://www.zigwheels.com/newcars/Ferrari/portofino',
#  'https://www.zigwheels.com/newcars/Ferrari/gtc4lusso',
#  'https://www.zigwheels.com/newcars/Ferrari/488-GTB',
#  'https://www.zigwheels.com/newcars/Ferrari/458-italia',
#  'https://www.zigwheels.com/newcars/Ferrari/458-speciale',
#  'https://www.zigwheels.com/newcars/Ferrari/458-spider',
#  'https://www.zigwheels.com/newcars/Ferrari/575-superamerica',
#  'https://www.zigwheels.com/newcars/Ferrari/599-gtb-fiorano',
#  'https://www.zigwheels.com/newcars/Ferrari/612',
#  'https://www.zigwheels.com/newcars/Ferrari/California-T',
#  'https://www.zigwheels.com/newcars/Ferrari/enzo',
#  'https://www.zigwheels.com/newcars/Ferrari/f430',
#  'https://www.zigwheels.com/newcars/Ferrari/f620-gt',
#  'https://www.zigwheels.com/newcars/Ferrari/FF',
#  'https://www.zigwheels.com/newcars/Land-Rover/Range-Rover',
#  'https://www.zigwheels.com/newcars/Land-Rover/Discovery-Sport',
#  'https://www.zigwheels.com/newcars/Land-Rover/Range-Rover-Evoque',
#  'https://www.zigwheels.com/newcars/Land-Rover/range-rover-velar',
#  'https://www.zigwheels.com/newcars/Land-Rover/discovery',
#  'https://www.zigwheels.com/newcars/Land-Rover/Range-Rover-Sport',
#  'https://www.zigwheels.com/newcars/Land-Rover/range-rover-evoque-2019',
#  'https://www.zigwheels.com/newcars/Land-Rover/defender',
#  'https://www.zigwheels.com/newcars/Land-Rover/discovery-3',
#  'https://www.zigwheels.com/newcars/Land-Rover/discovery-4',
#  'https://www.zigwheels.com/newcars/Land-Rover/freelander-2',
#  'https://www.zigwheels.com/newcars/Land-Rover/range-rover-2010-2012',
#  'https://www.zigwheels.com/newcars/Maserati/levante',
#  'https://www.zigwheels.com/newcars/Maserati/GranCabrio',
#  'https://www.zigwheels.com/newcars/Maserati/GranTurismo',
#  'https://www.zigwheels.com/newcars/Maserati/Ghibli',
#  'https://www.zigwheels.com/newcars/Maserati/Quattroporte',
#  'https://www.zigwheels.com/newcars/Bentley/Flying-Spur',
#  'https://www.zigwheels.com/newcars/Bentley/Continental',
#  'https://www.zigwheels.com/newcars/Bentley/bentayga',
#  'https://www.zigwheels.com/newcars/Bentley/Mulsanne',
#  'https://www.zigwheels.com/newcars/Bentley/arnage',
#  'https://www.zigwheels.com/newcars/Bentley/azure',
#  'https://www.zigwheels.com/newcars/Bentley/brooklands',
#  'https://www.zigwheels.com/newcars/ISUZU/D-Max-V-Cross',
#  'https://www.zigwheels.com/newcars/ISUZU/mu-x',
#  'https://www.zigwheels.com/newcars/ISUZU/d-max',
#  'https://www.zigwheels.com/newcars/ISUZU/D-Max-V-Cross-2015-2019',
#  'https://www.zigwheels.com/newcars/ISUZU/mu-7',
#  'https://www.zigwheels.com/newcars/Force-Motors/Gurkha',
#  'https://www.zigwheels.com/newcars/Force-Motors/Force-One',
#  'https://www.zigwheels.com/newcars/Force-Motors/trax-cruiser',
#  'https://www.zigwheels.com/newcars/Bajaj/re60',
#  'https://www.zigwheels.com/newcars/DC/Avanti',
#  'https://www.zigwheels.com/newcars/DC/tca',
#  'https://www.zigwheels.com/newcars/Lexus/ls',
#  'https://www.zigwheels.com/newcars/Lexus/nx',
#  'https://www.zigwheels.com/newcars/Lexus/rx',
#  'https://www.zigwheels.com/newcars/Lexus/lx',
#  'https://www.zigwheels.com/newcars/Lexus/es',
#  'https://www.zigwheels.com/newcars/Lexus/lc-500h',
#  'https://www.zigwheels.com/newcars/Lexus/ux',
#  'https://www.zigwheels.com/newcars/Premier/Rio',
#  'https://www.zigwheels.com/newcars/Premier/118-ne',
#  'https://www.zigwheels.com/newcars/Premier/138-d',
#  'https://www.zigwheels.com/newcars/Premier/padmini',
#  'https://www.zigwheels.com/newcars/Chevrolet/aveo',
#  'https://www.zigwheels.com/newcars/Chevrolet/aveo-u-va',
#  'https://www.zigwheels.com/newcars/Chevrolet/beat',
#  'https://www.zigwheels.com/newcars/Chevrolet/captiva',
#  'https://www.zigwheels.com/newcars/Chevrolet/cruze',
#  'https://www.zigwheels.com/newcars/Chevrolet/enjoy',
#  'https://www.zigwheels.com/newcars/Chevrolet/forester',
#  'https://www.zigwheels.com/newcars/Chevrolet/optra',
#  'https://www.zigwheels.com/newcars/Chevrolet/optra-magnum',
#  'https://www.zigwheels.com/newcars/Chevrolet/optra-srv',
#  'https://www.zigwheels.com/newcars/Chevrolet/Sail-Sedan',
#  'https://www.zigwheels.com/newcars/Chevrolet/sail',
#  'https://www.zigwheels.com/newcars/Chevrolet/Sail-Hatchback',
#  'https://www.zigwheels.com/newcars/Chevrolet/silverado',
#  'https://www.zigwheels.com/newcars/Chevrolet/spark',
#  'https://www.zigwheels.com/newcars/Chevrolet/Tavera-Neo-3',
#  'https://www.zigwheels.com/newcars/Chevrolet/tavera',
#  'https://www.zigwheels.com/newcars/Chevrolet/tavera-neo',
#  'https://www.zigwheels.com/newcars/Chevrolet/trailblazer',
#  'https://www.zigwheels.com/newcars/citroen/c5-aircross']

# %%
brand_all=[]        #List all brands name
model_all=[]        #List to store name of the product
variant_all=[]      #List all variants name
price_all=[]        #List to store price of the product
count=0
for i in link_model:
    count+=1
    url = i
    
#Seprating brand and model names from the link_list for easy analysing
    brand_index=i.rfind('/', 0, i.rfind('/'))
    model_index=i.rfind('/')
    brand=i[brand_index+1:model_index]
    model=i[model_index+1:]
    if model.find(brand,0,len(brand))>=0:
        model=model[len(brand)+1:]

#Gettig price of all cars from link_list and saving in price_all list
    try:
        response =urllib.request.urlopen(url)
        html = response.read()
        text = html.decode()
    except:
        print(count)
        continue
    
#Using regex function to search pattern of price of cars
    regex_v1=re.compile('<a href="/newcars/'+brand+'/'+model+'/([A-Za-z\-0-9]*)" data-track-component=')
        
    regex_p1=re.compile('<td width="28%" class="zw-tb-data fnt-16 modelName modelPrice hidden-xs">\nRs. ([0-9\.]+) lakh')
    regex_p2=re.compile('<td width="28%" class="zw-tb-data fnt-16 modelName modelPrice hidden-xs">\nRs. ([0-9\.]+) crore')
    
  
    price1=re.findall(regex_p1,text)
    price2=re.findall(regex_p2,text) 
    variant=re.findall(regex_v1,text)

#Once found price adding brand,model,variant and price in respective list,so index and length of all are same.
    for x in range(0,len(variant)):
        
        brand_all.append(brand)
        model_all.append(model)
        variant_all.append(variant[x])
        
#Checking whether price in Lakh Or Cr and appenidng it accrodingly and if price missing the filling by nan   
        try:
            if price1[x]:
                price_all.append(price1[x] +' Lakh')
            elif price2:
                price_all.append(price2[x] +' Cr')
            else:
                price_all.append('Nan')
        except:
            if price2:
                price_all.append(price2[x-len(price1)]+' Cr')
            else:
                price_all.append('Nan')
#     if count==10:
#         break

#print(brand_all)
#print(model_all)
#print(variant_all)
#print(price_all)
# Out:
# 161

# %%
print(len(brand_all))
print(len(model_all))
print(len(variant_all))
print(len(price_all))
#price_all.append(0)
# print(brand_all)
# print(model_all)
# print(variant_all)
# print(price_all)
# Out:
# 927
# 927
# 927
# 927

# %%
#creating a dataframe and appending brands,model,price and variant in cars and then saving as excel file
cars=pd.DataFrame()
cars['Brand']=np.array(brand_all)
cars['Model']=np.array(model_all)
cars['Variant']=np.array(variant_all)
cars['Price']=np.array(price_all)
cars.to_excel("zigcars_scrapped_data2.xlsx")
